# %%
import csvkit
import pandas as pd

# %%
import mysql.connector as connection
import MySQLdb

# %%
a=pd.read_excel("Superstore_USA.xlsx",sheet_name=0)
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)
b=pd.read_excel("Superstore_USA.xlsx",sheet_name=1)
c=pd.read_excel("Superstore_USA.xlsx",sheet_name=2)

# %%
mydb=connection.connect(host="localhost",user='root',password='Apurva29')

# %%
mydb

# %%
#2automatically dumbing table from csv file to superstoredata using csvkit library
# !csvsql --db mysql://root:Apurva29@127.0.0.1:3306/usa_superstore --insert Orders.csv
# Out:
# C:\Users\apurv\anaconda3\lib\site-packages\agate\table\from_csv.py:74: RuntimeWarning: Error sniffing CSV dialect: Could not determine delimiter
# C:\Users\apurv\anaconda3\lib\site-packages\agate\utils.py:285: UnnamedColumnWarning: Column 0 has no name. Using "a".
# sys:1: ResourceWarning: unclosed socket <zmq.Socket(zmq.PUSH) at 0x1847a88ee80>
# C:\Users\apurv\anaconda3\lib\site-packages\IPython\utils\_process_win32.py:124: ResourceWarning: unclosed file <_io.BufferedWriter name=4>
# C:\Users\apurv\anaconda3\lib\site-packages\IPython\utils\_process_win32.py:124: ResourceWarning: unclosed file <_io.BufferedReader name=5>
# C:\Users\apurv\anaconda3\lib\site-packages\IPython\utils\_process_win32.py:124: ResourceWarning: unclosed file <_io.BufferedReader name=6>

# %%
#2
# !csvsql --db mysql://root:Apurva29@127.0.0.1:3306/usa_superstore --insert Returns.csv
# Out:
# C:\Users\apurv\anaconda3\lib\site-packages\agate\utils.py:285: UnnamedColumnWarning: Column 0 has no name. Using "a".
# OperationalError: (MySQLdb.OperationalError) (1050, "Table 'returns' already exists")
# [SQL:
# CREATE TABLE `Returns` (
# 	a DECIMAL(38, 0) NOT NULL,
# 	`Order ID` DECIMAL(38, 0) NOT NULL,
# 	`Status` VARCHAR(8) NOT NULL
# )
#
# ]
# (Background on this error at: https://sqlalche.me/e/14/e3q8)
# C:\Users\apurv\anaconda3\lib\threading.py:914: ResourceWarning: unclosed file <_io.BufferedWriter name=4>
# C:\Users\apurv\anaconda3\lib\threading.py:914: ResourceWarning: unclosed file <_io.BufferedReader name=5>
# C:\Users\apurv\anaconda3\lib\threading.py:914: ResourceWarning: unclosed file <_io.BufferedReader name=6>
# sys:1: ResourceWarning: unclosed socket <zmq.Socket(zmq.PUSH) at 0x1847a7ef160>

# %%
#2
# !csvsql --db mysql://root:Apurva29@127.0.0.1:3306/usa_superstore --insert Users.csv
# Out:
# C:\Users\apurv\anaconda3\lib\site-packages\agate\utils.py:285: UnnamedColumnWarning: Column 0 has no name. Using "a".
# sys:1: ResourceWarning: unclosed socket <zmq.Socket(zmq.PUSH) at 0x1847c89c640>
# C:\Users\apurv\anaconda3\lib\site-packages\IPython\utils\_process_win32.py:124: ResourceWarning: unclosed file <_io.BufferedWriter name=4>
# C:\Users\apurv\anaconda3\lib\site-packages\IPython\utils\_process_win32.py:124: ResourceWarning: unclosed file <_io.BufferedReader name=5>
# C:\Users\apurv\anaconda3\lib\site-packages\IPython\utils\_process_win32.py:124: ResourceWarning: unclosed file <_io.BufferedReader name=6>

# %%
a
# Out:
#       Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID    Customer Name       Ship Mode Customer Segment Product Category           Product Sub-Category Product Container                                       Product Name  Product Base Margin   Region State or Province        City  Postal Code Order Date  Ship Date       Profit  Quantity ordered new    Sales  Order ID
# 0      18606  Not Specified      0.01        2.88           0.50            2  Janice Fletcher     Regular Air        Corporate  Office Supplies                         Labels         Small Box                                           Avery 49                 0.36  Central          Illinois     Addison        60101 2012-05-28 2012-05-30     1.320000                     2     5.90     88525
# ...

# %%
b
# Out:
#       Order ID    Status
# 0           65  Returned
# 1          612  Returned
# 2          614  Returned
# 3          678  Returned
# 4          710  Returned
# ...        ...       ...
# 1629    182681  Returned
# 1630    182683  Returned
# 1631    182750  Returned
# 1632    182781  Returned
# 1633    182906  Returned
#
# [1634 rows x 2 columns]

# %%
c
# Out:
#     Region  Manager
# 0  Central    Chris
# 1     East     Erin
# 2    South      Sam
# 3     West  William

# %%
cursor=mydb.cursor()

# %%
cursor.execute("use usa_superstore")

# %%
cursor.execute("select orders.OrderID, orders.ProductName , returns.OrderID from orders join returns on orders.OrderID=returns.OrderID")

# %%
#3....................................
cursor.fetchall()
# Out:
# [(Decimal('9895'), 'Dixon My First Ticonderoga Pencil, #2', Decimal('9895')),
#  (Decimal('13959'), 'Avery 493', Decimal('13959')),
#  (Decimal('13959'), 'EcoTones® Memo Sheets', Decimal('13959')),
#  (Decimal('36038'), 'Newell 35', Decimal('36038')),
#  (Decimal('39490'), 'Staples SlimLine Pencil Sharpener', Decimal('39490')),
#  (Decimal('39490'), 'Hon Non-Folding Utility Tables', Decimal('39490')),
#  (Decimal('37760'),
#   '80 Minute Slim Jewel Case CD-R , 10/Pack - Staples',
#   Decimal('37760')),
#  (Decimal('37760'), 'Accessory34', Decimal('37760')),
#  (Decimal('37414'),
#   'Chromcraft Bull-Nose Wood 48" x 96" Rectangular Conference Tables',
#   Decimal('37414')),
#  (Decimal('47265'), 'Xerox 1983', Decimal('47265')),
#  (Decimal('7079'),
#   'Hon 2090 “Pillow Soft” Series Mid Back Swivel/Tilt Chairs',
#   Decimal('7079')),
#  (Decimal('7079'),
#   'Eureka Recycled Copy Paper 8 1/2" x 11", Ream',
#   Decimal('7079')),
#  (Decimal('8353'), 'Newell 343', Decimal('8353')),
# ...

# %%
#4...................................
cursor.execute("select orders.OrderID,orders.ProductName,returns.Status from orders join returns on orders.OrderID=returns.OrderID")

# %%
cursor.fetchall()
# Out:
# [(Decimal('9895'), 'Dixon My First Ticonderoga Pencil, #2', 'Returned'),
#  (Decimal('13959'), 'Avery 493', 'Returned'),
#  (Decimal('13959'), 'EcoTones® Memo Sheets', 'Returned'),
#  (Decimal('36038'), 'Newell 35', 'Returned'),
#  (Decimal('39490'), 'Staples SlimLine Pencil Sharpener', 'Returned'),
#  (Decimal('39490'), 'Hon Non-Folding Utility Tables', 'Returned'),
#  (Decimal('37760'),
#   '80 Minute Slim Jewel Case CD-R , 10/Pack - Staples',
#   'Returned'),
#  (Decimal('37760'), 'Accessory34', 'Returned'),
#  (Decimal('37414'),
#   'Chromcraft Bull-Nose Wood 48" x 96" Rectangular Conference Tables',
#   'Returned'),
#  (Decimal('47265'), 'Xerox 1983', 'Returned'),
#  (Decimal('7079'),
#   'Hon 2090 “Pillow Soft” Series Mid Back Swivel/Tilt Chairs',
#   'Returned'),
#  (Decimal('7079'),
#   'Eureka Recycled Copy Paper 8 1/2" x 11", Ream',
#   'Returned'),
#  (Decimal('8353'), 'Newell 343', 'Returned'),
# ...

# %%
#5....................................
cursor.execute("select count(*) from (select CustomerName from orders group by CustomerName) as alia")

# %%
cursor.fetchall()
# Out:
# [(2703,)]

# %%
#6...................................
cursor.execute("select orders.ProductName,users.Region,users.Manager from orders join users on orders.Region=users.Region")

# %%
#7...................................
cursor.fetchall()
# Out:
# [('Avery 49', 'Central', 'Chris'),
#  ('SANFORD Liquid Accent™ Tank-Style Highlighters', 'West', 'William'),
#  ('Xerox 1968', 'West', 'William'),
#  ('Acme® Preferred Stainless Steel Scissors', 'West', 'William'),
#  ('V70', 'West', 'William'),
#  ('Xerox 194', 'West', 'William'),
#  ('Canon S750 Color Inkjet Printer', 'West', 'William'),
#  ('Global Troy™ Executive Leather Low-Back Tilter', 'West', 'William'),
#  ('Xerox 1930', 'West', 'William'),
#  ('Kensington 6 Outlet MasterPiece® HOMEOFFICE Power Control Center',
#   'West',
#   'William'),
#  ('Xerox 21', 'West', 'William'),
#  ('*Staples* Highlighting Markers', 'West', 'William'),
#  ('Accessory34', 'West', 'William'),
#  ('Xerox 1933', 'East', 'Erin'),
#  ('Sauder Forest Hills Library, Woodland Oak Finish', 'East', 'Erin'),
#  ('Riverside Furniture Stanwyck Manor Table Series', 'East', 'Erin'),
#  ('Park Ridge™ Embossed Executive Business Envelopes', 'East', 'Erin'),
# ...

# %%
cursor.execute("select (select count(ShipMode) from orders where ShipMode='Regular Air')*(100)/(select count(ShipMode) from orders)")

# %%
cursor.fetchall()
# Out:
# [(Decimal('74.6446'),)]

# %%
cursor.execute("select (select count(ShipMode) from orders where ShipMode= 'Express Air')*(100)/(select count(ShipMode) from orders) as percent")

# %%
cursor.fetchall()
# Out:
# [(Decimal('11.7441'),)]

# %%
cursor.execute('select (select count(ShipMode) from orders where ShipMode="Delivery Truck")*(100)/(select count(ShipMode) from orders) as percent')

# %%
cursor.fetchall()
# Out:
# [(Decimal('13.6113'),)]

# %%
#8.................................
cursor.execute("alter table orders add Delivery_time int(255)")
cursor.execute("update orders as o1 set Delivery_time=(select o1.ShipDate-o1.OrderDate)")

# %%
#9
cursor.execute("select OrderID,Delivery_time from orders where Delivery_time >10")

# %%
#10
cursor.execute("select orders.Delivery_time from orders join returns on orders.OrderID=returns.OrderID where orders.Delivery_time >15")

# %%
#11
cursor.execute("select orders.Region, sum(orders.Profit) as Profit from orders group by orders.Region order by Profit desc limit 1")

# %%
cursor.fetchall()
# Out:
# [('Central', Decimal('519825.567066599978743273'))]

# %%
#12...........................
cursor.execute("select orders.Region, sum(orders.Discount) as discount from orders group by Region order by discount desc limit 1")

# %%
cursor.fetchall()
# Out:
# [('Central', Decimal('143.06'))]

# %%
#13........................
cursor.execute("select PostalCode from orders group by PostalCode")

# %%
#14...................................
cursor.execute("select CustomerSegment,sum(Profit) as profit from orders group by CustomerSegment order by profit desc limit 1")

# %%
#15.........................
cursor.execute('select ProductCategory,sum(Profit) as profit from orders group by ProductCategory order by profit asc limit 1')

# %%
#16..........
cursor.execute("select ProductName,sum(ProductBaseMargin) as profit from orders group by ProductName order by profit desc limit 10")
